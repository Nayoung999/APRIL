# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayoung999/APRIL/blob/main/%ED%81%AC%EB%A1%A4%EB%A7%81_%EC%B4%88%EC%BD%94%ED%8C%8C%EC%9D%B4%EC%8D%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 크롤링 연습

import urllib.request
from bs4 import BeautifulSoup

# 접근할 페이지 번호
pageNum = 1

# 저장할 이미지 경로 및 이름
imageNum = 1
imageDir = "/content/drive/MyDrive/choco/n_"

while pageNum < 7: # 필요한 페이지에 맞추기

  url = "https://unionvinyl.co.kr/product/list.html?cate_no=26&page="
  url = url + str(pageNum)

  fp = urllib.request.urlopen(url)
  source = fp.read();
  fp.close()

  soup = BeautifulSoup(source, "html.parser")
  soup = soup.findAll("div", class_ = "prdImg")

  # 이미지 경로 받아 로컬에 저장
  for i in soup:
    imageNum += 1
    imgURL = i.find("img")["src"]
    urllib.request.urlretrieve("https:"+imgURL, imageDir + str(imageNum).zfill(4) + ".jpg")
    print(imgURL)
    print(imageNum)

  pageNum += 1
# Out:
# //unionvinyl.co.kr/web/product/medium/202204/fcb8fed5e85ef93ed4eeb2e147815c58.jpg
# 2
# //unionvinyl.co.kr/web/product/medium/202204/b40234ffdec735501fd6fc17a6fec64c.jpg
# 3
# //unionvinyl.co.kr/web/product/medium/202204/25e0013a589746e88a04695644d668ac.jpg
# 4
# //unionvinyl.co.kr/web/product/medium/202204/a7f8a7bb88e672a5e03ffb730204c4ff.jpg
# 5
# //unionvinyl.co.kr/web/product/medium/202204/208cc26c627cfba236c2a444aa9b4410.jpg
# 6
# //unionvinyl.co.kr/web/product/medium/202204/c0cda7c1a2919212c6c356ecb253de1b.jpg
# 7
# //unionvinyl.co.kr/web/product/medium/202204/254f112a4428a342ed3407fdf2b942bc.jpg
# 8
# //unionvinyl.co.kr/web/product/medium/202204/f31c6fb7391bb1354401103292e85dea.jpg
# 9
# //unionvinyl.co.kr/web/product/medium/202204/ea2d5295298dbd981bcfc4017740fc9c.jpg
# 10
# //unionvinyl.co.kr/web/product/medium/202203/2d879c6d21ab875bc582a0fab227cd92.jpg
# 11
# //unionvinyl.co.kr/web/product/medium/202203/b9c50ea8b7b86ce3c4f989783acc4b4f.jpg
# 12
# ...

# %%
# 수정 시 
# 저장 경로 안에서 출처 별로 폴더를 나누자!?

# %%
# 어프어프

import urllib.request
from bs4 import BeautifulSoup

# 접근할 페이지 번호
pageNum = 1

# 저장할 이미지 경로 및 이름
imageNum = 0
imageDir = "/content/drive/MyDrive/choco/earpearp/n_hard_"

while pageNum < 109: # 필요한 페이지에 맞추기

  url = "http://earpearp.com/product/list.html?cate_no=130&page="
  url = url + str(pageNum)

  fp = urllib.request.urlopen(url)
  source = fp.read();
  fp.close()

  soup = BeautifulSoup(source, "html.parser")
  soup = soup.findAll("div", class_ = "prdImg")

  # 이미지 경로 받아 로컬에 저장
  for i in soup:
    imageNum += 1
    imgURL = i.find("img")["src"]
    urllib.request.urlretrieve("https:"+imgURL, imageDir + str(imageNum).zfill(4) + ".jpg")
    print(imgURL)
    print(imageNum)

  pageNum += 1
# Out:
# //earpearp.com/web/product/big/202204/73752a1e66b042de5d278bc2305e8db9.jpg
# 1
# //earpearp.com/web/product/big/202204/a454c3d917bc8e910cf41ddb76da8384.jpg
# 2
# //earpearp.com/web/product/big/202204/a5dbd69c874fd805d647638c464cd03e.jpg
# 3
# //earpearp.com/web/product/big/202204/e586a5d23e43eee8aff78117e8898bdc.jpg
# 4
# //earpearp.com/web/product/big/202204/7c8d4155590fe6056358b812dd31d308.jpg
# 5
# //earpearp.com/web/product/big/202204/b4d055702a5735d842e4167f76dec115.jpg
# 6
# //earpearp.com/web/product/big/202204/ee7bc033ef78a64cea6d5dcc71256560.jpg
# 7
# //earpearp.com/web/product/big/202204/e906bb74df3c2b540707465d9f4d9add.jpg
# 8
# //earpearp.com/web/product/big/202204/be1dad04893c46bc2fbb68dceea2fe08.jpg
# 9
# //earpearp.com/web/product/big/202202/ef6d7744c5145b147470318eb4413790.jpg
# 10
# //earpearp.com/web/product/big/202202/adbf0b72153d1943973b1a31696e8524.jpg
# 11
# //earpearp.com/web/product/big/202202/050cc6eff1824da40695fff7012e334a.jpg
# 12
# ...

# %%
# 위글위글

import urllib.request
from bs4 import BeautifulSoup

# 접근할 페이지 번호
pageNum = 1

# 저장할 이미지 경로 및 이름
imageNum = 0
imageDir = "/content/drive/MyDrive/choco/wigglewiggle/n_hard_"

while pageNum < 7: # 필요한 페이지에 맞추기

  url ="m.wiggle-wiggle.com/product/list_thumb.html?cate_no=133&page="
  url = url + str(pageNum)

  fp = urllib.request.urlopen(url)
  source = fp.read();
  fp.close()

  soup = BeautifulSoup(source, "html.parser")
  soup = soup.findAll("div", class_ = "prdImg")

  # 이미지 경로 받아 로컬에 저장
  for i in soup:
    imageNum += 1
    imgURL = i.find("img")["src"]
    urllib.request.urlretrieve("https:"+imgURL, imageDir + str(imageNum).zfill(4) + ".jpg")
    print(imgURL)
    print(imageNum)

  pageNum += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f228a90d7878> in <module>()
#      16   url = url + str(pageNum)
#      17
# ---> 18   fp = urllib.request.urlopen(url)
#      19   source = fp.read();
#      20   fp.close()
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     508         # accept a URL or a Request object
#     509         if isinstance(fullurl, str):
# --> 510             req = Request(fullurl, data)
#     511         else:
#     512             req = fullurl
#
# ...

# %%
2
